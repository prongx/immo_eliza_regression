# %% [markdown]
#  # Immo Eliza data analysis

# %% [markdown]
# ### Dataset
#
# - start 15000
#
# - after claning 11483

# %% [markdown]
# ### What is the correlation between the variables and the price?

# %% [markdown]
# ![corr_heatmap.png](attachment:corr_heatmap.png)

# %% [markdown]
# ### Outliers

# %% [markdown]
# ![a_price_livingarea.png](attachment:a_price_livingarea.png)

# %% [markdown]
# ![h_price_livingarea.png](attachment:h_price_livingarea.png)

# %% [markdown]
# ### The most and least expensive districts.

# %% [markdown]
# ![price_district.png](attachment:price_district.png)

# %% [markdown]
# ### Variables to delete
# - Fireplace - negative correlation to price (-0.069)
# - Furnished - very low correlation to price (0.1)

# %% [markdown]
# ### Most important variables
# - living area
# - number of rooms
# - terrace + area
# - garden + area
# - land_surface
