# %% [markdown]
# # Modelling simple linear regression on APARTMENT dataset

# %%
import pandas as pd
df = pd.read_csv('../data/dataset_APARTMENT.csv')

# %%
df.head()
# Out:
#    postalCode     price  n_rooms  living_area  equipped_kitchen  fireplace  \
# 0      1070.0  170000.0      2.0         64.0               1.0        0.0
# 1      4680.0  219000.0      3.0        124.0               1.0        0.0
# 2      9600.0  219000.0      1.0        120.0               1.0        0.0
# 3      9300.0  245000.0      1.0         52.0               1.0        0.0
# 4      1000.0  330000.0      2.0         90.0               1.0        0.0
#
#    terrace  area_terrace  garden  area_garden  n_facades
# 0      1.0           2.0     0.0          0.0        2.0
# 1      1.0          21.0     1.0         46.0        4.0
# 2      0.0           0.0     1.0       2000.0        4.0
# 3      1.0          10.0     0.0          0.0        2.0
# 4      1.0           8.0     0.0          0.0        2.0

# %%
X = df['living_area'].values
y = df['price'].values
print(type(X))
print(type(y))
print(X.shape)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# (5811,)

# %%
import matplotlib.pyplot as plt
plt.scatter(x = df['living_area'], y = df['price'])
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state= 42)

# %%
from sklearn.linear_model import LinearRegression

X_train = X_train.reshape(-1,1)
y_train = y_train.reshape(-1,1)
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regressor.score(X_train,y_train)
# Out:
# 0.2736643078126735

# %%
X_test = X_test.reshape(-1,1)
y_test = y_test.reshape(-1,1)

y_pred = regressor.predict(X_test)
print(y_pred)
# Out:
# [[339743.12729017]
#  [311558.07385648]
#  [413728.89255363]
#  ...
#  [529992.23796763]
#  [272803.62538514]
#  [290419.2837812 ]]

# %%
regressor.score(X_test, y_test)
# Out:
# 0.2613842339843254

# %%
plt.plot(X_train, regressor.predict(X_train))
plt.scatter(X_train,y_train, color = 'red')
plt.title('living_area vs price (Training set)')
plt.xlabel('living_area')
plt.ylabel('price')
plt.show()

# %%
plt.plot(X_test, regressor.predict(X_test))
plt.scatter(X_test,y_test, color = 'red')
plt.title('living_area vs price (Testing set)')
plt.xlabel('living_area')
plt.ylabel('price')
plt.show()
